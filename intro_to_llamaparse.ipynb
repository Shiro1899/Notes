# %% [markdown]
# # Using LlamaParse to retrieve text from PDFs stored in either S3 bucket or local computer

# %%
# install modules
pip install llama-index s3fs boto3

# %%
# Uncomment if you are in a Jupyter Notebook
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## 1. Creating and uploading files in an S3 bucket in AWS

# %%
import boto3

# %%
endpoint_url = (
    "http://localhost:4566"  # use this line if you are using S3 via localstack
)
# endpoint_url = None  # use this line if you are using real AWS S3


bucket_name = "llama-index-test-bucket"
s3 = boto3.resource("s3", endpoint_url=endpoint_url) #creates a resource object for interacting with the S3 storage
s3.create_bucket(Bucket=bucket_name) #creates new s3 bucket
bucket = s3.Bucket(bucket_name) # selects a S3 bucket based on its name

#.upload_file() uploads the files into the selected bucket
# put the paul graham essays in the test-bucket in various subdirectories
bucket.upload_file(
    "data/paul_graham/paul_graham_essay1.txt", "essays/paul_graham_essay1.txt"
)
bucket.upload_file(
    "data/paul_graham/paul_graham_essay2.txt",
    "essays/more_essays/paul_graham_essay2.txt",
)
bucket.upload_file(
    "data/paul_graham/paul_graham_essay3.txt",
    "essays/even_more_essays/paul_graham_essay3.txt",
)

# %% [markdown]
# ## 2. Creating an S3FileSystem Instance

# %%
from s3fs import S3FileSystem

# %%
# Use this code if you'll only use it for testing
s3_fs = S3FileSystem(key="...", secret="...")

# %%
# Use this code instead to reduce security risks
endpoint_url = (
    "http://localhost:4566"  # use this line if you are using S3 via localstack
)

s3_fs = S3FileSystem(anon=False, # disallows anonymous access without credentials
                     endpoint_url=endpoint_url) # should be defined elsewhere in the code

# %%
from llama_index.core import SimpleDirectoryReader  # pip install llama-index

# %% [markdown]
# ## 3. Create reader object

# %%
# option A: create reader object that reads into S3 buckets

bucket_name = "my-document-bucket" #S3 bucket name

reader = SimpleDirectoryReader(
    input_dir=bucket_name,
    fs=s3_fs, # fs means file system. use the instance (file system object) created earlier in s3_fs
    recursive=True,  # recursively searches all subdirectories
)

# %%
# option B: create reader object that reads into local computer
from llama_parse import LlamaParse

parser = LlamaParse(
    api_key = "", # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type = "text" # "markdown" and "text" are available
)

file_extractor = {".pdf": parser}

reader = SimpleDirectoryReader(input_dir="./sample_data", 
                            #    required_exts=[".pdf", ".docx"],
                                file_extractor=file_extractor,
                                recursive=False, # doesn't get files from subdirectories also
                                num_files_limit= 3) #sets number of documents to read

# %% [markdown]
# ## 4. Loading data

# %% [markdown]
# To extract the text data using the reader object. You either use *.iter_data()* or *.load_data()*
#
# *.load_data()* - loads ALL of the documents first (one by one) and you can't do anything but wait til everything is loaded. Outputs a list
#
# *.iter_data()* - You can do anything each time a single document has been loaded. Outputs an object

# %%
# Results of using load_data()
documents = reader.load_data()
documents
# Out:
# Started parsing the file under job_id fab74a44-17c5-4432-948f-ab40886cc6a1
# Started parsing the file under job_id ba186038-c93c-4157-a659-7e1f91edf18d
# Started parsing the file under job_id 770bae17-4f1c-49ae-8d32-1e7ed0df46c6
# [Document(id_='11703026-bd5d-42f3-8c80-a76c7cd5f6cc', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_name': '03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_type': 'application/pdf', 'file_size': 1816568, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='GLOBAL LEADER IN\nLIGHTWEIGHT ROOFING                                                                        ONDULINE® Classic\nSOLUTIONS\n\n\n\nONDULINE is well recognized globally in\nthe construction industry with 80 years\nof experience offering guaranteed\nprotection for buildings\nand people beneath.\n\n\n\nONDULINE is present in more than100\ncountries      providing       clients     with\necologically responsible roofing and\nwaterproofing solutions.                                Scan this to know more\n\n\n\nONDULINE products are asbestos-free and\nare fully committed to customers\nsatisfaction and planet environment\npreservation.\n\n\n\n                                                      /ondulinephilippines@onduline_ph\n                                                      0917 713 5616  www.ph.onduline.com\nIn the Philippines, ONDULINE started its\noperations in 2012 in Taguig City, having\nwarehouse in Cebu and Valenzuela to\nefficiently serve our clients.                   BROWSE     SHOP   CONNECT\n                                                            Basta roofing;                Onduline\n---\nColor Range                                                                                            Installation Procedure\n                                                                                                         1. Laying of Purlins                                              2. Fixing of sheets         Halfsheet\n\n\n\n                                                                                                              Fix the bottom purlin      .                                                        Fullsheet\n                                                                                                              The purlin spacing has to be maintained at 45cm.                                      opposite end of the roof\n                                                                                                              Ensure that the purlins are in one straight line &             from prevailing winds.\n                                                                                                               parallel to each other.                                       Cut a sheet in half vertically, and use to lay sheets\n                                                                                                           • 5-10 degrees (24cm purlin spacing) - 20pcs screws (8+4+4+4)     courses in a broken bond pattern.\n                  BLACK classic                                        BROWN classic                       a. SIDE overlap - 2 corrugations                                  Using  a  broken  bond  pattern reduces  the overall\n                                                                                                           b. Top Overlap - 32cm sheets                                      thickness of the structure. Follow this for every alternate\n                                                                                                           • 10 degrees up (45cm purlin spacing) - 14pcs screws (5+3+3+3)    row.\n                                                                                                    ...
#  Document(id_='a9e89223-95b4-4b27-b43b-56f79615d7d7', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduvilla-tile_compressed_0.pdf', 'file_name': '03-2024-onduvilla-tile_compressed_0.pdf', 'file_type': 'application/pdf', 'file_size': 2387566, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='GLOBAL LEADER IN\nLIGHTWEIGHT ROOFING                                                                                   ONDUVILLA  ®\nSOLUTIONS\n\n\n\nONDULINE is well recognized globally\nin   the    construction      industry     with\n80     years     of    experience offering\nguaranteed       protection     for buildings\nand people beneath.\n\n\n\nONDULINE is present in more than 100\ncountries      providing       clients     with\necologically responsible roofing and\nwaterproofing solutions.                                Scan this to know more\n\n\n\nONDULINE products are asbestos-free\nand are fully committed to customers\nsatisfaction and planet environment\npreservation.\n\n\n\n                                                       /ondulinephilippines@onduline_ph\nIn the Philippines, ONDULINE started                   0917 713 5616   www.ph.onduline.com\nits operations in 2012 in Taguig City,\nhaving     warehouse        in   Cebu      and\nValenzuela to efficiently serve our              BROWSE            CONNECT\nclients.                                                     SHOP\n                                                            Basta roofing;                  Onduline\n---\nColor Range                                                                         Installation principles\n                                                                                    Laying of purlins - Purlins have to be                                                              Ridge for pitch above 30                0\n                                                                                    placed at    32cm distance, centre to\n  PIGMENTED COLORS                                                                  centre. Since there is   an overhang of\n                                                                                    5cm    at   the  eaves,   the    distance\n                                                                                    between the first and second purlin is\n                                                                                    27cm, centre to centre.\n\n\n\n              \x1f\x1e\x1d\x1c\x1b\x1c\x1a\x19\x1b\x1c                                      \x1f\x1e\x1d\x1c\x1b\x1c\x1a\x11\x17\x1b\x1b\x14                                                                Start installation at eave, in the opposite\n                                                                                                                                          direction of the  prevailing wind. Position   The Slim cap can be used for                      The corrugated ventilated filler\n                                                                                                                                          the dark strip on top.   Stagger the rows,    pitches up to 300. Above that                     can be fixed below the ridge\n                                                                                                                                          by starting the second row with a half tile.  limit, the standard ridge piece                   piece, in order to prevent birds\n                                                                                      ...
#  Document(id_='c097c6d6-724a-4c3a-8782-95d4a30b4c76', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\092123_ModernBamboo_Catalogue.pdf', 'file_name': '092123_ModernBamboo_Catalogue.pdf', 'file_type': 'application/pdf', 'file_size': 9046826, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='MODERN BAMBOO\n   THE BAMBOO EXPERT\n      CATALOGUE 2023\n---\n m\n MODERNOBEZAMBOO"\n                         AA                             Mcponaks\nFinished project: Mcdo Calasiao, Pangasinan\n                        Eco-Friendly Sustainable Material\n           Cladding      Flooring      Decking      Ceiling     Baffle  Slats\n---\nmb  \'BAMBOO                                                                                    THE BAMBOO EXPERT\nMOCEAM\n    ABOUT US\n    At Modern Bamboo, we are dedicated to provid-\n   ing   high-quality;   eco-friendly,     and   sustainable\n    materials for flooring; walls, and ceilings, both for\n   indoor and outdoor spaces. Our mission is to offer\n   innovative and  stylish       solutions   that not only\n   enhance the aesthetics of your living or working\n   environment but also contribute            to    greener;\n    more sustainable future:\n    We understand the importance of preserving our\n    planet  and  minimizing     our ecological footprint:\n    That\'s why all our products are carefully sourced\n   and manufactured with           strong commitment to\n   sustainability:    We     specialize    in   bamboo,\n   fast-growing and renewable resource that offers\n   remarkable strength       and durability while       being\n   gentle on the environment,                                   NEIRO PINES   MWN\n    WHY CHOOSE US?\n    Discover Modern Bamboo, your go-to destination\n   for   eco-friendly    and    sustainable    materials   for\n   indoor and outdoor flooring; walls,          and ceilings.\n    With our carefully sourced bamboo products, we\n   offer      stylish   and   environmentally      conscious\n   choice for your design needs. Choose us for excep-\n   tional quality, versatile styles, and expert guidance,\n    as we   strive to make        positive impact      on our\n   planet while creating stunning spaces that inspire_\n   OUR COMMITMENTS\n   At Modern Bamboo, we are committed to building\n      sustainable future: We        prioritize   eco-friendly\n   sourcing; using renewable materials like bamboo to\n   reduce    deforestation.     Our    manufacturing      pro-\n    cesses are  designed to be sustainable; minimizing\n   waste and emissions We provide high-quality and\n   durable products that stand the test of time_           Our\n   versatile design solutions offer style and function-\n   ality while minimizing environmental impact: Join\n   us in creating       greener;   more sustainable world\n   through our commitment to eco-friendly practices:\n     WWWmodernbamboo-ph              f@modernbamboo               0  0939 905 8051  0917 100 9173       0939 918 0160\n---\nmb  \'BAMBOO                                                                                          THE BAMBOO EXPERT\nModeRH\n            Quality Raw Materials                        E1 Standard                             Advanced    Technology\n            We use 5-byear old matured                   We use 8 coats of                       Our partner manufacturing\n            bamboo which is most                         odorless, healthy and                   plant has over 20 years of\n            compact, most durable and                    scratch resistant German               experience   ...

# %%
# Results of using iter_data()
documents = reader.iter_data()
documents
# Out:
# <generator object SimpleDirectoryReader.iter_data at 0x0000021EE3A99900>

# %%
# .iter_data() method
documents = []
doc_num = 1
for docs in reader.iter_data():
    print(f"Loading document #{doc_num}...")

    print("unstructured look of the loaded document:")
    print(docs)
    print("|")
    for doc in docs:
        # before modification
        print("Id and text obtained from the loaded document:")
        print(doc)
        print("||")
        
        # do something with the doc
        doc.text = doc.text.upper()

        # after modification
        print("modified text of the loaded document:")
        print(doc)
        print("||||")

        #add doc to all_docs
        documents.append(doc)
        
    doc_num += 1
documents #weird because it's showing docs not doc
# Out:
# Started parsing the file under job_id 37520e1c-e92f-4903-86c8-e19e692a84d6
# Loading document #1...
# unstructured look of the loaded document:
# [Document(id_='b2faefc2-bcb9-4c71-a42f-e79a2ab88f6f', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_name': '03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_type': 'application/pdf', 'file_size': 1816568, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='GLOBAL LEADER IN\nLIGHTWEIGHT ROOFING                                                                        ONDULINE® Classic\nSOLUTIONS\n\n\n\nONDULINE is well recognized globally in\nthe construction industry with 80 years\nof experience offering guaranteed\nprotection for buildings\nand people beneath.\n\n\n\nONDULINE is present in more than100\ncountries      providing       clients     with\necologically responsible roofing and\nwaterproofing solutions.                                Scan this to know more\n\n\n\nONDULINE products are asbestos-free and\nare fully committed to customers\nsatisfaction and planet environment\npreservation.\n\n\n\n                                                      /ondulinephilippines@onduline_ph\n                                                      0917 713 5616  www.ph.onduline.com\nIn the Philippines, ONDULINE started its\noperations in 2012 in Taguig City, having\nwarehouse in Cebu and Valenzuela to\nefficiently serve our clients.                   BROWSE     SHOP   CONNECT\n                                                            Basta roofing;                Onduline\n---\nColor Range                                                                                            Installation Procedure\n                                                                                                         1. Laying of Purlins                                              2. Fixing of sheets         Halfsheet\n\n\n\n                                                                                                              Fix the bottom purlin      .                                                        Fullsheet\n                                                                                                              The purlin spacing has to be maintained at 45cm.                                      opposite end of the roof\n                                                                                                              Ensure that the purlins are in one straight line &             from prevailing winds.\n                                                                                                               parallel to each other.                                       Cut a sheet in half vertically, and use to lay sheets\n                                                                                                           • 5-10 degrees (24cm purlin spacing) - 20pcs screws (8+4+4+4)     courses in a broken bond pattern.\n                  BLACK classic                                        BROWN classic                       a. SIDE overlap - 2 corrugations                                  Using  a  broken  bond  pattern reduces  the overall\n                                                                                                           b. Top Overlap - 32cm sheets                                      thickness of the structure. Follow this for every alternate\n                                                                                                           • 10 degrees up (45cm purlin spacing) - 14pcs screws (5+3+3+3)    row.\n                                                                                                    ...
# |
# Id and text obtained from the loaded document:
# Doc ID: b2faefc2-bcb9-4c71-a42f-e79a2ab88f6f
# Text: GLOBAL LEADER IN LIGHTWEIGHT ROOFING
# ONDULINE® Classic SOLUTIONS    ONDULINE is well recognized globally in
# the construction industry with 80 years of experience offering
# guaranteed protection for buildings and people beneath.    ONDULINE is
# present in more than100 countries ...
# ||
# modified text of the loaded document:
# Doc ID: b2faefc2-bcb9-4c71-a42f-e79a2ab88f6f
# Text: GLOBAL LEADER IN LIGHTWEIGHT ROOFING
# ONDULINE® CLASSIC SOLUTIONS    ONDULINE IS WELL RECOGNIZED GLOBALLY IN
# THE CONSTRUCTION INDUSTRY WITH 80 YEARS OF EXPERIENCE OFFERING
# GUARANTEED PROTECTION FOR BUILDINGS AND PEOPLE BENEATH.    ONDULINE IS
# PRESENT IN MORE THAN100 COUNTRIES ...
# ||||
# Started parsing the file under job_id 4d315fc5-6959-4181-b1ba-088204c990e2
# Loading document #2...
# unstructured look of the loaded document:
# [Document(id_='60ad3bcc-285e-4cff-a0de-50cb6c8642aa', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduvilla-tile_compressed_0.pdf', 'file_name': '03-2024-onduvilla-tile_compressed_0.pdf', 'file_type': 'application/pdf', 'file_size': 2387566, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='GLOBAL LEADER IN\nLIGHTWEIGHT ROOFING                                                                                   ONDUVILLA  ®\nSOLUTIONS\n\n\n\nONDULINE is well recognized globally\nin   the    construction      industry     with\n80     years     of    experience offering\nguaranteed       protection     for buildings\nand people beneath.\n\n\n\nONDULINE is present in more than 100\ncountries      providing       clients     with\necologically responsible roofing and\nwaterproofing solutions.                                Scan this to know more\n\n\n\nONDULINE products are asbestos-free\nand are fully committed to customers\nsatisfaction and planet environment\npreservation.\n\n\n\n                                                       /ondulinephilippines@onduline_ph\nIn the Philippines, ONDULINE started                   0917 713 5616   www.ph.onduline.com\nits operations in 2012 in Taguig City,\nhaving     warehouse        in   Cebu      and\nValenzuela to efficiently serve our              BROWSE            CONNECT\nclients.                                                     SHOP\n                                                            Basta roofing;                  Onduline\n---\nColor Range                                                                         Installation principles\n                                                                                    Laying of purlins - Purlins have to be                                                              Ridge for pitch above 30                0\n                                                                                    placed at    32cm distance, centre to\n  PIGMENTED COLORS                                                                  centre. Since there is   an overhang of\n                                                                                    5cm    at   the  eaves,   the    distance\n                                                                                    between the first and second purlin is\n                                                                                    27cm, centre to centre.\n\n\n\n              \x1f\x1e\x1d\x1c\x1b\x1c\x1a\x19\x1b\x1c                                      \x1f\x1e\x1d\x1c\x1b\x1c\x1a\x11\x17\x1b\x1b\x14                                                                Start installation at eave, in the opposite\n                                                                                                                                          direction of the  prevailing wind. Position   The Slim cap can be used for                      The corrugated ventilated filler\n                                                                                                                                          the dark strip on top.   Stagger the rows,    pitches up to 300. Above that                     can be fixed below the ridge\n                                                                                                                                          by starting the second row with a half tile.  limit, the standard ridge piece                   piece, in order to prevent birds\n                                                                                      ...
# |
# Id and text obtained from the loaded document:
# Doc ID: 60ad3bcc-285e-4cff-a0de-50cb6c8642aa
# Text: GLOBAL LEADER IN LIGHTWEIGHT ROOFING
# ONDUVILLA  ® SOLUTIONS    ONDULINE is well recognized globally in
# the    construction      industry     with 80     years     of
# experience offering guaranteed       protection     for buildings and
# people beneath.    ONDUL...
# ||
# modified text of the loaded document:
# Doc ID: 60ad3bcc-285e-4cff-a0de-50cb6c8642aa
# Text: GLOBAL LEADER IN LIGHTWEIGHT ROOFING
# ONDUVILLA  ® SOLUTIONS    ONDULINE IS WELL RECOGNIZED GLOBALLY IN
# THE    CONSTRUCTION      INDUSTRY     WITH 80     YEARS     OF
# EXPERIENCE OFFERING GUARANTEED       PROTECTION     FOR BUILDINGS AND
# PEOPLE BENEATH.    ONDUL...
# ||||
# Started parsing the file under job_id db684a3e-0d3e-4be6-b9f6-c6dba57bd4c1
# Loading document #3...
# unstructured look of the loaded document:
# [Document(id_='4803bd10-87ac-497d-8a8e-28e7f12b6847', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\092123_ModernBamboo_Catalogue.pdf', 'file_name': '092123_ModernBamboo_Catalogue.pdf', 'file_type': 'application/pdf', 'file_size': 9046826, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='MODERN BAMBOO\n   THE BAMBOO EXPERT\n      CATALOGUE 2023\n---\n m\n MODERNOBEZAMBOO"\n                         AA                             Mcponaks\nFinished project: Mcdo Calasiao, Pangasinan\n                        Eco-Friendly Sustainable Material\n           Cladding      Flooring      Decking      Ceiling     Baffle  Slats\n---\nmb  \'BAMBOO                                                                                    THE BAMBOO EXPERT\nMOCEAM\n    ABOUT US\n    At Modern Bamboo, we are dedicated to provid-\n   ing   high-quality;   eco-friendly,     and   sustainable\n    materials for flooring; walls, and ceilings, both for\n   indoor and outdoor spaces. Our mission is to offer\n   innovative and  stylish       solutions   that not only\n   enhance the aesthetics of your living or working\n   environment but also contribute            to    greener;\n    more sustainable future:\n    We understand the importance of preserving our\n    planet  and  minimizing     our ecological footprint:\n    That\'s why all our products are carefully sourced\n   and manufactured with           strong commitment to\n   sustainability:    We     specialize    in   bamboo,\n   fast-growing and renewable resource that offers\n   remarkable strength       and durability while       being\n   gentle on the environment,                                   NEIRO PINES   MWN\n    WHY CHOOSE US?\n    Discover Modern Bamboo, your go-to destination\n   for   eco-friendly    and    sustainable    materials   for\n   indoor and outdoor flooring; walls,          and ceilings.\n    With our carefully sourced bamboo products, we\n   offer      stylish   and   environmentally      conscious\n   choice for your design needs. Choose us for excep-\n   tional quality, versatile styles, and expert guidance,\n    as we   strive to make        positive impact      on our\n   planet while creating stunning spaces that inspire_\n   OUR COMMITMENTS\n   At Modern Bamboo, we are committed to building\n      sustainable future: We        prioritize   eco-friendly\n   sourcing; using renewable materials like bamboo to\n   reduce    deforestation.     Our    manufacturing      pro-\n    cesses are  designed to be sustainable; minimizing\n   waste and emissions We provide high-quality and\n   durable products that stand the test of time_           Our\n   versatile design solutions offer style and function-\n   ality while minimizing environmental impact: Join\n   us in creating       greener;   more sustainable world\n   through our commitment to eco-friendly practices:\n     WWWmodernbamboo-ph              f@modernbamboo               0  0939 905 8051  0917 100 9173       0939 918 0160\n---\nmb  \'BAMBOO                                                                                          THE BAMBOO EXPERT\nModeRH\n            Quality Raw Materials                        E1 Standard                             Advanced    Technology\n            We use 5-byear old matured                   We use 8 coats of                       Our partner manufacturing\n            bamboo which is most                         odorless, healthy and                   plant has over 20 years of\n            compact, most durable and                    scratch resistant German               experience   ...
# |
# Id and text obtained from the loaded document:
# Doc ID: 4803bd10-87ac-497d-8a8e-28e7f12b6847
# Text: MODERN BAMBOO    THE BAMBOO EXPERT       CATALOGUE 2023 ---  m
# MODERNOBEZAMBOO"                          AA
# Mcponaks Finished project: Mcdo Calasiao, Pangasinan
# Eco-Friendly Sustainable Material            Cladding      Flooring
# Decking      Ceiling     Baffle  Slats --- mb  'BAMBOO      ...
# ||
# modified text of the loaded document:
# Doc ID: 4803bd10-87ac-497d-8a8e-28e7f12b6847
# Text: MODERN BAMBOO    THE BAMBOO EXPERT       CATALOGUE 2023 ---  M
# MODERNOBEZAMBOO"                          AA
# MCPONAKS FINISHED PROJECT: MCDO CALASIAO, PANGASINAN
# ECO-FRIENDLY SUSTAINABLE MATERIAL            CLADDING      FLOORING
# DECKING      CEILING     BAFFLE  SLATS --- MB  'BAMBOO      ...
# ||||
# [Document(id_='b2faefc2-bcb9-4c71-a42f-e79a2ab88f6f', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_name': '03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_type': 'application/pdf', 'file_size': 1816568, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='GLOBAL LEADER IN\nLIGHTWEIGHT ROOFING                                                                        ONDULINE® CLASSIC\nSOLUTIONS\n\n\n\nONDULINE IS WELL RECOGNIZED GLOBALLY IN\nTHE CONSTRUCTION INDUSTRY WITH 80 YEARS\nOF EXPERIENCE OFFERING GUARANTEED\nPROTECTION FOR BUILDINGS\nAND PEOPLE BENEATH.\n\n\n\nONDULINE IS PRESENT IN MORE THAN100\nCOUNTRIES      PROVIDING       CLIENTS     WITH\nECOLOGICALLY RESPONSIBLE ROOFING AND\nWATERPROOFING SOLUTIONS.                                SCAN THIS TO KNOW MORE\n\n\n\nONDULINE PRODUCTS ARE ASBESTOS-FREE AND\nARE FULLY COMMITTED TO CUSTOMERS\nSATISFACTION AND PLANET ENVIRONMENT\nPRESERVATION.\n\n\n\n                                                      /ONDULINEPHILIPPINES@ONDULINE_PH\n                                                      0917 713 5616  WWW.PH.ONDULINE.COM\nIN THE PHILIPPINES, ONDULINE STARTED ITS\nOPERATIONS IN 2012 IN TAGUIG CITY, HAVING\nWAREHOUSE IN CEBU AND VALENZUELA TO\nEFFICIENTLY SERVE OUR CLIENTS.                   BROWSE     SHOP   CONNECT\n                                                            BASTA ROOFING;                ONDULINE\n---\nCOLOR RANGE                                                                                            INSTALLATION PROCEDURE\n                                                                                                         1. LAYING OF PURLINS                                              2. FIXING OF SHEETS         HALFSHEET\n\n\n\n                                                                                                              FIX THE BOTTOM PURLIN      .                                                        FULLSHEET\n                                                                                                              THE PURLIN SPACING HAS TO BE MAINTAINED AT 45CM.                                      OPPOSITE END OF THE ROOF\n                                                                                                              ENSURE THAT THE PURLINS ARE IN ONE STRAIGHT LINE &             FROM PREVAILING WINDS.\n                                                                                                               PARALLEL TO EACH OTHER.                                       CUT A SHEET IN HALF VERTICALLY, AND USE TO LAY SHEETS\n                                                                                                           • 5-10 DEGREES (24CM PURLIN SPACING) - 20PCS SCREWS (8+4+4+4)     COURSES IN A BROKEN BOND PATTERN.\n                  BLACK CLASSIC                                        BROWN CLASSIC                       A. SIDE OVERLAP - 2 CORRUGATIONS                                  USING  A  BROKEN  BOND  PATTERN REDUCES  THE OVERALL\n                                                                                                           B. TOP OVERLAP - 32CM SHEETS                                      THICKNESS OF THE STRUCTURE. FOLLOW THIS FOR EVERY ALTERNATE\n                                                                                                           • 10 DEGREES UP (45CM PURLIN SPACING) - 14PCS SCREWS (5+3+3+3)    ROW.\n                                                                                                    ...
#  Document(id_='60ad3bcc-285e-4cff-a0de-50cb6c8642aa', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduvilla-tile_compressed_0.pdf', 'file_name': '03-2024-onduvilla-tile_compressed_0.pdf', 'file_type': 'application/pdf', 'file_size': 2387566, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='GLOBAL LEADER IN\nLIGHTWEIGHT ROOFING                                                                                   ONDUVILLA  ®\nSOLUTIONS\n\n\n\nONDULINE IS WELL RECOGNIZED GLOBALLY\nIN   THE    CONSTRUCTION      INDUSTRY     WITH\n80     YEARS     OF    EXPERIENCE OFFERING\nGUARANTEED       PROTECTION     FOR BUILDINGS\nAND PEOPLE BENEATH.\n\n\n\nONDULINE IS PRESENT IN MORE THAN 100\nCOUNTRIES      PROVIDING       CLIENTS     WITH\nECOLOGICALLY RESPONSIBLE ROOFING AND\nWATERPROOFING SOLUTIONS.                                SCAN THIS TO KNOW MORE\n\n\n\nONDULINE PRODUCTS ARE ASBESTOS-FREE\nAND ARE FULLY COMMITTED TO CUSTOMERS\nSATISFACTION AND PLANET ENVIRONMENT\nPRESERVATION.\n\n\n\n                                                       /ONDULINEPHILIPPINES@ONDULINE_PH\nIN THE PHILIPPINES, ONDULINE STARTED                   0917 713 5616   WWW.PH.ONDULINE.COM\nITS OPERATIONS IN 2012 IN TAGUIG CITY,\nHAVING     WAREHOUSE        IN   CEBU      AND\nVALENZUELA TO EFFICIENTLY SERVE OUR              BROWSE            CONNECT\nCLIENTS.                                                     SHOP\n                                                            BASTA ROOFING;                  ONDULINE\n---\nCOLOR RANGE                                                                         INSTALLATION PRINCIPLES\n                                                                                    LAYING OF PURLINS - PURLINS HAVE TO BE                                                              RIDGE FOR PITCH ABOVE 30                0\n                                                                                    PLACED AT    32CM DISTANCE, CENTRE TO\n  PIGMENTED COLORS                                                                  CENTRE. SINCE THERE IS   AN OVERHANG OF\n                                                                                    5CM    AT   THE  EAVES,   THE    DISTANCE\n                                                                                    BETWEEN THE FIRST AND SECOND PURLIN IS\n                                                                                    27CM, CENTRE TO CENTRE.\n\n\n\n              \x1f\x1e\x1d\x1c\x1b\x1c\x1a\x19\x1b\x1c                                      \x1f\x1e\x1d\x1c\x1b\x1c\x1a\x11\x17\x1b\x1b\x14                                                                START INSTALLATION AT EAVE, IN THE OPPOSITE\n                                                                                                                                          DIRECTION OF THE  PREVAILING WIND. POSITION   THE SLIM CAP CAN BE USED FOR                      THE CORRUGATED VENTILATED FILLER\n                                                                                                                                          THE DARK STRIP ON TOP.   STAGGER THE ROWS,    PITCHES UP TO 300. ABOVE THAT                     CAN BE FIXED BELOW THE RIDGE\n                                                                                                                                          BY STARTING THE SECOND ROW WITH A HALF TILE.  LIMIT, THE STANDARD RIDGE PIECE                   PIECE, IN ORDER TO PREVENT BIRDS\n                                                                                      ...
#  Document(id_='4803bd10-87ac-497d-8a8e-28e7f12b6847', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\092123_ModernBamboo_Catalogue.pdf', 'file_name': '092123_ModernBamboo_Catalogue.pdf', 'file_type': 'application/pdf', 'file_size': 9046826, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='MODERN BAMBOO\n   THE BAMBOO EXPERT\n      CATALOGUE 2023\n---\n M\n MODERNOBEZAMBOO"\n                         AA                             MCPONAKS\nFINISHED PROJECT: MCDO CALASIAO, PANGASINAN\n                        ECO-FRIENDLY SUSTAINABLE MATERIAL\n           CLADDING      FLOORING      DECKING      CEILING     BAFFLE  SLATS\n---\nMB  \'BAMBOO                                                                                    THE BAMBOO EXPERT\nMOCEAM\n    ABOUT US\n    AT MODERN BAMBOO, WE ARE DEDICATED TO PROVID-\n   ING   HIGH-QUALITY;   ECO-FRIENDLY,     AND   SUSTAINABLE\n    MATERIALS FOR FLOORING; WALLS, AND CEILINGS, BOTH FOR\n   INDOOR AND OUTDOOR SPACES. OUR MISSION IS TO OFFER\n   INNOVATIVE AND  STYLISH       SOLUTIONS   THAT NOT ONLY\n   ENHANCE THE AESTHETICS OF YOUR LIVING OR WORKING\n   ENVIRONMENT BUT ALSO CONTRIBUTE            TO    GREENER;\n    MORE SUSTAINABLE FUTURE:\n    WE UNDERSTAND THE IMPORTANCE OF PRESERVING OUR\n    PLANET  AND  MINIMIZING     OUR ECOLOGICAL FOOTPRINT:\n    THAT\'S WHY ALL OUR PRODUCTS ARE CAREFULLY SOURCED\n   AND MANUFACTURED WITH           STRONG COMMITMENT TO\n   SUSTAINABILITY:    WE     SPECIALIZE    IN   BAMBOO,\n   FAST-GROWING AND RENEWABLE RESOURCE THAT OFFERS\n   REMARKABLE STRENGTH       AND DURABILITY WHILE       BEING\n   GENTLE ON THE ENVIRONMENT,                                   NEIRO PINES   MWN\n    WHY CHOOSE US?\n    DISCOVER MODERN BAMBOO, YOUR GO-TO DESTINATION\n   FOR   ECO-FRIENDLY    AND    SUSTAINABLE    MATERIALS   FOR\n   INDOOR AND OUTDOOR FLOORING; WALLS,          AND CEILINGS.\n    WITH OUR CAREFULLY SOURCED BAMBOO PRODUCTS, WE\n   OFFER      STYLISH   AND   ENVIRONMENTALLY      CONSCIOUS\n   CHOICE FOR YOUR DESIGN NEEDS. CHOOSE US FOR EXCEP-\n   TIONAL QUALITY, VERSATILE STYLES, AND EXPERT GUIDANCE,\n    AS WE   STRIVE TO MAKE        POSITIVE IMPACT      ON OUR\n   PLANET WHILE CREATING STUNNING SPACES THAT INSPIRE_\n   OUR COMMITMENTS\n   AT MODERN BAMBOO, WE ARE COMMITTED TO BUILDING\n      SUSTAINABLE FUTURE: WE        PRIORITIZE   ECO-FRIENDLY\n   SOURCING; USING RENEWABLE MATERIALS LIKE BAMBOO TO\n   REDUCE    DEFORESTATION.     OUR    MANUFACTURING      PRO-\n    CESSES ARE  DESIGNED TO BE SUSTAINABLE; MINIMIZING\n   WASTE AND EMISSIONS WE PROVIDE HIGH-QUALITY AND\n   DURABLE PRODUCTS THAT STAND THE TEST OF TIME_           OUR\n   VERSATILE DESIGN SOLUTIONS OFFER STYLE AND FUNCTION-\n   ALITY WHILE MINIMIZING ENVIRONMENTAL IMPACT: JOIN\n   US IN CREATING       GREENER;   MORE SUSTAINABLE WORLD\n   THROUGH OUR COMMITMENT TO ECO-FRIENDLY PRACTICES:\n     WWWMODERNBAMBOO-PH              F@MODERNBAMBOO               0  0939 905 8051  0917 100 9173       0939 918 0160\n---\nMB  \'BAMBOO                                                                                          THE BAMBOO EXPERT\nMODERH\n            QUALITY RAW MATERIALS                        E1 STANDARD                             ADVANCED    TECHNOLOGY\n            WE USE 5-BYEAR OLD MATURED                   WE USE 8 COATS OF                       OUR PARTNER MANUFACTURING\n            BAMBOO WHICH IS MOST                         ODORLESS, HEALTHY AND                   PLANT HAS OVER 20 YEARS OF\n            COMPACT, MOST DURABLE AND                    SCRATCH RESISTANT GERMAN               EXPERIENCE   ...

# %%
# .iter_data() method
documents = []
doc_num = 1
for idx, docs in reader.iter_data():
    for doc in docs:
        print(f"{idx} - {doc.metadata['file_name']} - {doc.text}")
        print(f"-------------------------------------------------------------------------------------------")
        documents.append(doc)
        
    doc_num += 1
documents #weird because it's showing docs not doc
# Out:
# Started parsing the file under job_id 114e2952-1d3b-4d07-baba-a26d1cee0355
# 2 - 03-2024-onduline-classic-brochure_compressed_2.pdf - GLOBAL LEADER IN
# LIGHTWEIGHT ROOFING                                                                        ONDULINE® Classic
# SOLUTIONS
#
#
#
# ONDULINE is well recognized globally in
# the construction industry with 80 years
# of experience offering guaranteed
# protection for buildings
# and people beneath.
#
#
#
# ONDULINE is present in more than100
# countries      providing       clients     with
# ecologically responsible roofing and
# waterproofing solutions.                                Scan this to know more
#
#
#
# ONDULINE products are asbestos-free and
# are fully committed to customers
# satisfaction and planet environment
# preservation.
#
#
#
#                                                       /ondulinephilippines@onduline_ph
#                                                       0917 713 5616  www.ph.onduline.com
# In the Philippines, ONDULINE started its
# operations in 2012 in Taguig City, having
# warehouse in Cebu and Valenzuela to
# efficiently serve our clients.                   BROWSE     SHOP   CONNECT
#                                                             Basta roofing;                Onduline
# ---
# Color Range                                                                                            Installation Procedure
#                                                                                                          1. Laying of Purlins                                              2. Fixing of sheets         Halfsheet
#
#
#
#                                                                                                               Fix the bottom purlin      .                                                        Fullsheet
#                                                                                                               The purlin spacing has to be maintained at 45cm.                                      opposite end of the roof
#                                                                                                               Ensure that the purlins are in one straight line &             from prevailing winds.
#                                                                                                                parallel to each other.                                       Cut a sheet in half vertically, and use to lay sheets
#                                                                                                            • 5-10 degrees (24cm purlin spacing) - 20pcs screws (8+4+4+4)     courses in a broken bond pattern.
#                   BLACK classic                                        BROWN classic                       a. SIDE overlap - 2 corrugations                                  Using  a  broken  bond  pattern reduces  the overall
#                                                                                                            b. Top Overlap - 32cm sheets                                      thickness of the structure. Follow this for every alternate
#                                                                                                            • 10 degrees up (45cm purlin spacing) - 14pcs screws (5+3+3+3)    row.
#                                                                                                            a. SIDE overlap - 1 corrugation
#                                                                                                            b. b.Top Overlap – 20cm
#
#
#
#                                                                                                          Roof pitches       10-15               3. Following the overlapping rules
#                                                                                                          Maximum purlin     45cm                is important   to  ensure  a  total
#                                                                                                          distance                               waterpr        over time. Side and
#                                                                                                                                                 end overlapping vary according
#                                                                                                                                                 to the roof pitches.                                                                             Features/Advantages
#
#
#
#                                                                                                                                                       For the end overlap, use minimum 20 cm.
#                                                                                                         Overhang            7cm                       For the side overlap, use minimum
#                  GREEN classic                                            RED classic                   at eaves                                      1 corrugation.                  Minimum of 14 screws should be drilled
#                                                                                                                                                                                       per sheet:                                                                      ONDULINE®is a non-ferrous product, therefore
#                                                                                                                                                                                            5 screws at each corrugation at the
#                                                                                                         Minimum end         20cm                                                           end overlap or eaves                                                       resists corrosion from sea, 100% no rust.
# Product Characteristics                                                                                 overlap                                                                            3 screws at      intermediate purlin of
#                                                                                                                                                                                            the sheet                                                                  Onduline® has been installed in beach area
#                                                                                                                                                                                            3 screws at second intermediate purlin
#                                                                                                                                                                                            of the sheet                                     Rustproof                 around the world.
#                                                                                                                                                                                            3 screws at third intermediate purlin of
#    Length                                                                                200cm           Minimum side       1 corrugation                                                  the sheet
#                                                                                                                                                                                       As   Onduline is a           material, it is
#    Width                                                                                  95 cm          overlap                                                                      important  to follow the         order and
#    Thickness                                                                             3 mm                                                                                         pattern.
#    Height of Corrugation                                                                 38 mm                                                                  4. Sheet fixing                                                                                       Due to its sound insulating property,
#                                                                                                                                                                   Select the correct type of drill screw to suit purlin type.
#    Pitch of Module                                                                      95 mm                                                                     Place the head of the drill screw in the socket of thedrive                                         ONDULINE® products Absorb the noise of
#                                                                                                  2                                                                tool. Align the top side of the corrugation with the centre
#    Surface                                                                               1.90 m                                                                   of the purlin.                                                                                      heavy rain. ONDULINE® is a recommended roof
#                                                                                                                                                                   Drive the drill screw through the top of the corrugation and                 Acoustic
#    Weight of Product                                                                     6.5 kg                                                                   the purlin until the corrugation is correctly stressed.                                             solution for a quite house, but also for school.
#                           2                                                                         2                                                             The use of the drill with an adjustable torque setting is               Performance
#    Weight per m                                                                        3.4 kg/m                                                                   recommended to avoid over compressing the
#                                                                                                                                                                   corrugation.
#    Number of Corrugations                                                                 10                                                                      Always use Onduline fasteners for sh             .
#
#
#
#                                                                                                          5. Ridge fixing
#                                                                                                             Add an extra purlin when necessary if the distance                                                                                                        ONDULINE® thermal conductivity is close to the
#                                                                                                             between the last purlin and the ridge is greater than 15cm.
# Accessories                                                                                                 Start        the ridge at opposite end of the roof from                                                                                                   one of cork. In a tropical endurance test,
#                                                                                                             prevailing winds.
#                                                                                                             Maintain 15 cm minimum overlapping between ridges.                                                                                                        ONDULINE® proved suitable in severe humidity.
#                                                                                                                                                        6. Rubber Filler(Optional)                                                              Thermal
#                                  Flexible double wings accommodate a wide range of                                                                     Our Corrugated Ventilated Filler is designed to prevent birds                         Insulation
#                                  roof angles which helps avoid water to penetrate                                                                      and other animal to enter into the roof space, at the eave and    ridge.
#                                  into the building.                                                                                                      Easy to install
#                                                                                                                                                          Available in all Onduvilla colors
#         Onduline RIDGES                                                                                                                                 15-year warranty
#                                                                                                                   7. Hips                                                                                                                                             ONDULINE® sheets ensure protection, it can
#                                                                                                                      Fix the hip before the ridge.
#                                  steel or wood purlins.                                                              Fasten the ridge to the purlins.                                                                                                                 withstand wind speeds up to 260kph on
#                                                                                                                      Overlay and clean the ridges if necessary.                                                                                Typhoon                wooden purlin and 225 kph on steel purlin.
#         Speedy SCREWS                                                                                                                                  8. Valleys                                                                             Resistant
#
#
#
#                                                                                                                                                           The vertical valley depth should be 7.5 cm.
#                                                                                                                                                           The sheets are cut across (parallel to the valley line).
#                                                                                                                                                           The overhang is 4 cm.
#                                                                                                                                                           Valleys could be either metal or Onduline supplied.                                                         ONDULINE® roofs are guaranteed to remain
#
#
#
#              ONDUTAPE                                                                                         9. Curved roofs
#                                                                                                               When the frame design is established, continuously setup                                                                                                usage, when fixed and maintained in strict
#                                                                                                               the lines courses to get the right positions of purlins.
#                                                                                                               Onduline sheets are recommended for curved structures                                                                            Durable                accordance with the fixing instructions.
#                                  and ridges, preventing ingress of water and dusts.                           with minimum radius of 6m.
#
#
#
#                                                                                                               * For detailed                        , please contact
#           RUBBER FILLER                                                                                        our technical department.
# -------------------------------------------------------------------------------------------
# Started parsing the file under job_id c36dd067-9853-4774-aac1-34d6e1fc3039
# 2 - 03-2024-onduvilla-tile_compressed_0.pdf - GLOBAL LEADER IN
# LIGHTWEIGHT ROOFING                                                                                   ONDUVILLA  ®
# SOLUTIONS
#
#
#
# ONDULINE is well recognized globally
# in   the    construction      industry     with
# 80     years     of    experience offering
# guaranteed       protection     for buildings
# and people beneath.
#
#
#
# ONDULINE is present in more than 100
# countries      providing       clients     with
# ecologically responsible roofing and
# waterproofing solutions.                                Scan this to know more
#
#
#
# ONDULINE products are asbestos-free
# and are fully committed to customers
# satisfaction and planet environment
# preservation.
#
#
#
#                                                        /ondulinephilippines@onduline_ph
# In the Philippines, ONDULINE started                   0917 713 5616   www.ph.onduline.com
# its operations in 2012 in Taguig City,
# having     warehouse        in   Cebu      and
# Valenzuela to efficiently serve our              BROWSE            CONNECT
# clients.                                                     SHOP
#                                                             Basta roofing;                  Onduline
# ---
# Color Range                                                                         Installation principles
#                                                                                     Laying of purlins - Purlins have to be                                                              Ridge for pitch above 30                0
#                                                                                     placed at    32cm distance, centre to
#   PIGMENTED COLORS                                                                  centre. Since there is   an overhang of
#                                                                                     5cm    at   the  eaves,   the    distance
#                                                                                     between the first and second purlin is
#                                                                                     27cm, centre to centre.
#
#
#
#                                                                                                                     Start installation at eave, in the opposite
#                                                                                                                                           direction of the  prevailing wind. Position   The Slim cap can be used for                      The corrugated ventilated filler
#                                                                                                                                           the dark strip on top.   Stagger the rows,    pitches up to 300. Above that                     can be fixed below the ridge
#                                                                                                                                           by starting the second row with a half tile.  limit, the standard ridge piece                   piece, in order to prevent birds
#                                                                                                                                           Horizontal overlaps are one corrugation.
#                                                                                                                                           Ensure proper waterproofing by aligning       should be used. Thanks to the                     or other animals entering into
#                                                                                                                                           the overlapping guides.                       higher pitch, the apron piece                     the      roof       space.        Overlap
#                                                                                                                                                             is not necessary and the ridge                    between        ridges     needs     to   be
#                                                                                                                                                                                         is watertight.                                    maintained at 15cm.
#
#
#
# Product Characteristics                                                             Fixing                                                                                              Valley
#                                                                                     ONDUVILLA® is to be fixed at each
#   Length                                                               107 cm       overlap     and     corrugation      with
#   Width                                                                40 cm        ONDUVILLA® fasteners
#   Thickness                                                            3 mm         Fix   the   tiles following   the  order
#                                                                                     described    above,    between    the   2
#   Height of Corrugation                                                38 mm        overlapping guides. Do not fix those
#                                                                                     corrugations that will be overlapped
#   Pitch of Module                                                     195 mm        by the next tile or verge piece
#   Gross Surface                                                        0.43 m   2
#   Weight of Product                                                    1.3 kg       Ridges                                                                                              Prepare the support.                              Fix     the     screws        on     top     of
#   Weight per gross surface                                            3.1 kg/m   2  Ensure that the maximum distance from the ridge point to the                                                                                          corrugations, into the supporting
#   Corrugation + Flats                                                   6 + 5       next purlin is 15 cm.                                                                                                                                 batten.
#                                                                                     If necessary, add an extra purlin to maintain this distance                                         Side wall Abutment
#                                                                                     Ridge for pitch below 30                0                                                           Fix the tile to the side wall with an aluminium Z-profile. Secure
# Accessories                                                                                                                                                                             the watertightness with a silicone mastic.
#
#
#
#                            Large and flexible ridge piece which is needed for
#                            roofs with pitch above 30 degrees. Does not require
#     Onduline RIDGES        additional waterproofing device.
#     900mm x 420mm
#
#
#
#                            Self drilling screw for fastening of roofing sheet to    At low pitches a ventilation gap of 1cm is         At the verge, the apron piece has to be cut
#                                                                                     necessary     between     the   flat parts   of    on site parallel to the last corrugation of the
#                            steel and wood purlins.                                  ONDUVILLA®       tiles. Fix  the  verge   piece    tile. Fix the overlaps with plastic clips that   Apron Abutment
#                                                                                     before the installation of the elements of the     also secure the gap of ventilation between
#     Speedy SCREWS                                                                   ridge.                                             left and right apron pieces and ridge.           Aluminium Z profile is fixed to the wall, and a line of silicon
#      4.2mm x 65mm                                                                                                                                                                       mastic is necessary for the watertightness.
#
#
#
#                            Designated to provide a neat weatherproof seal at
#                            the edge of the roof, can be used for both sides.
#
#
#
#         VERGE
#   1040mm x 109mm
#
#
#
#                                                                                     Like the tiles, apron pieces and slim caps are     Slim caps and closure cap have to be fixed
#                            Self adhesive flashing tape used for water tightness     to be overlapped against prevailing wind.          on top of the corrugations. If necessary, for a
#                            at the hips.                                                                                                better adaptation to the slope of the roof,
#                                                                                                                                        part B of the closure cap has to be cut on         * For detailed technical fixing guidelines, please contact our technical department.
#      ONDUBAND                                                                                                                          site.
# -------------------------------------------------------------------------------------------
# Started parsing the file under job_id 2359765c-7bf5-4034-a893-84e5c4642d20
# 2 - 092123_ModernBamboo_Catalogue.pdf - MODERN BAMBOO
#    THE BAMBOO EXPERT
#       CATALOGUE 2023
# ---
#  m
#  MODERNOBEZAMBOO"
#                          AA                             Mcponaks
# Finished project: Mcdo Calasiao, Pangasinan
#                         Eco-Friendly Sustainable Material
#            Cladding      Flooring      Decking      Ceiling     Baffle  Slats
# ---
# mb  'BAMBOO                                                                                    THE BAMBOO EXPERT
# MOCEAM
#     ABOUT US
#     At Modern Bamboo, we are dedicated to provid-
#    ing   high-quality;   eco-friendly,     and   sustainable
#     materials for flooring; walls, and ceilings, both for
#    indoor and outdoor spaces. Our mission is to offer
#    innovative and  stylish       solutions   that not only
#    enhance the aesthetics of your living or working
#    environment but also contribute            to    greener;
#     more sustainable future:
#     We understand the importance of preserving our
#     planet  and  minimizing     our ecological footprint:
#     That's why all our products are carefully sourced
#    and manufactured with           strong commitment to
#    sustainability:    We     specialize    in   bamboo,
#    fast-growing and renewable resource that offers
#    remarkable strength       and durability while       being
#    gentle on the environment,                                   NEIRO PINES   MWN
#     WHY CHOOSE US?
#     Discover Modern Bamboo, your go-to destination
#    for   eco-friendly    and    sustainable    materials   for
#    indoor and outdoor flooring; walls,          and ceilings.
#     With our carefully sourced bamboo products, we
#    offer      stylish   and   environmentally      conscious
#    choice for your design needs. Choose us for excep-
#    tional quality, versatile styles, and expert guidance,
#     as we   strive to make        positive impact      on our
#    planet while creating stunning spaces that inspire_
#    OUR COMMITMENTS
#    At Modern Bamboo, we are committed to building
#       sustainable future: We        prioritize   eco-friendly
#    sourcing; using renewable materials like bamboo to
#    reduce    deforestation.     Our    manufacturing      pro-
#     cesses are  designed to be sustainable; minimizing
#    waste and emissions We provide high-quality and
#    durable products that stand the test of time_           Our
#    versatile design solutions offer style and function-
#    ality while minimizing environmental impact: Join
#    us in creating       greener;   more sustainable world
#    through our commitment to eco-friendly practices:
#      WWWmodernbamboo-ph              f@modernbamboo               0  0939 905 8051  0917 100 9173       0939 918 0160
# ---
# mb  'BAMBOO                                                                                          THE BAMBOO EXPERT
# ModeRH
#             Quality Raw Materials                        E1 Standard                             Advanced    Technology
#             We use 5-byear old matured                   We use 8 coats of                       Our partner manufacturing
#             bamboo which is most                         odorless, healthy and                   plant has over 20 years of
#             compact, most durable and                    scratch resistant German               experience   using the most
#             most suited for bamboo                       Treffert paint:                        advanced technology        in
#             flooring-                                    The formaldehyde                       manufacturing:
#                                                          component of our
#                                                          bamboo flooring is up       to
#                                                          E1 European Standard.
#            High-tech Locking & PE Foam                   Termite Treated                       Trusted Supplier
#            Click locking system for easy                 Our planks are                         Our company has been
#            installation, removal and repair:             treated against                       supplying     construction
#            It is more high-tech, stable, and            termites                                materials since 2010     and
#            convenient compared to the                                                          is conveniently located
#            normal T&G     locking  system_                                                     along EDSA Pasay:
#            We use PE foam with special
#            HDPE layer:
#      WWWmodernbamboo-ph                f@Omodernbamboo            0   0939 905 8051      0917 100 9173        0939 918 0160
# ---
#  Pecan Brown                  5565/B0X (zuucs)    ACCESSORIES     Walnut Brown                     3900/BOX (Gpcs)    ACCESSORIES
#   1020 * 130 * 15mm                    Baseboard   T Molding        1850 x 135 x 14mm         Baseboard   T Molding   End Profile
#                                   End Profile Quarter Round                                          Stair Nosing Quarter Round
#                                3900/ BOX (6pcs)                                                    390UI BUL (ucsL
# Natural Yellow                        T Molding   ACCESSORIES        Tea Brown                                        ACCESSORIES
#    1850 x 135 * 14mm       Baseboard              End Profile                                 Baseboard   T Molding   End Profile
#                                  Stair Nosing  Quarter Round        1850 x 135 * 14mm                Stair Nosing Quarter Round
#   Nordic Oak                  42931BUL (zuucss    ACCESSORIES     Walnut Brown                    4293/B0X (20pcs)    Aacessories
#                                                    Baseboard                                                          Baseboard
#    610 x 130 * 14mm   HERRINGBONE       Molding   End Profile        610 x 130 x 14mm    HERRINGBONE      T Molding   End Profile
#                                  Stair Nosing  Quarter Round                                         Stair Nosing Quarter Round
#                                                                    MODERN BAMBOO
#                                39UUUL UusL                                 THE BAMBOO EXPERT
#   Nordic Oak               Baseboard              acessories
#   1850 x 135 x 14mm                    T Molding  End Profile
#                                  Stair Nosing  Quarter Round
# WWWmodernbamboo-ph             f@modernbamboo                  0  0939 905 8051        0917 100 9173       0939 918 0160
# ---
# mb                                                                                                                   THE BAMBOO EXPERT
# MODERN BAMBOO
#           Bamboo Flooring Accessories
#          BASEBOARDIWALL BASE                                        TMOLDING                                END PROFILE        THRESHOLD
#  Walnut Brown; Tea Brown Natural Yellow; Nordic OakWalnut Brown; Tea Brown Natural Yellow; Nordic Oak Walnut Brown; Tea Brown Natural Yellow; Nordic Oak
#    1830 x 60 x 14mm: 1200/PC                         1830 x 48 x 14mm: 1200/PC                          1830 x 50 x 24mm: 1200/PC
#                    Pecan Brown                                       Pecan Brown                                        Pecan Brown
#    1900 x 80 x 1Smm: 1000/PC                         1900 x 50 x 1Smm: 1000/PC                          1900 x 52 x 24mm: 1000/PC
#                     Purpose:                                          Purpose:                                           Purpose:
#       A decorative molding that is nailed           Used as transition between floorings with          Used as transition between floorings with
#      down to the wall ontop:     It is also to              same height; placed at the                   different height; usually placed at the
#   cover the gap of bamboo flooring and wall                       gap  of the door                            gap  of the door going to the
#                                                                                                                    bathroom/balcony
#                                        QUARTER ROUND                                       STAIR NOSING
#                           Walnut Brown; Tea Brown, Natural Yellow; Nordic OakWalnut Brown; Tea Brown,Natural Yellow; Nordic Oak
#                             1830 x 18 x 18mm: 1200/PC                        1830 x 83 x 24mm: 2000/PC
#                                             Pecan Brown
#                             1900 x 15 x 15mm: 100O/PC
#                                              Purpose:                                          Purpose:
#                                   Used on the base of the wall                  Used on the front edge of stair step
#                                against baseboard to cover the gap
#                                between flooring and wall; can also
#                                    be fuctioned as baseboard
#      WWW modernbamboo ph                  f@OJmodernbamboo                   0   0939 905 8051          0917 100 9173          0939 918 0160
# ---
# mb                                                                            THE BAMBOO EXPERT
# MOdERN BAMBOO
#              Nordic Uak UNDoonv
#                       7     Modern Bamboo         Cladding Small Wave            P215ubo /PC
# Stallualtd                             2900 x 140 x 18mm
#               INYES
#          Nordic LOak'~(INDOORD
#                              Modern Bamboo         Cladding Big Wave             P25] w JPC
# Stallldard                             2900 x 140 x 18mm
# moi                                                                              DOOR
#                                                                                          G
#                                       Modern Bamboo        Slat                       P780/PC
# Staluualu                               2900 x 20x 30mm
# mb_
#       Standard         Walnut    Modern Bamboo"       Cladding Flat           Pecan Brown (NDOOR)
# PJbUpt 1860x 103 x 8mm                                        2900 x 105 X 8mm       Pbsuxt
#     WWW.modernbamboo-ph     f@OJmodernbamboo        0 0939 905 8051  0917 100 9173   0939 918 0160
# ---
# mb                                                                                                                               THE BAMBOO EXPERT
# HODERN BAMBOO
#                                                     P1197 &4/PC                    Standard     Walnut                                    P119784 /PC
#         Bamboo Decking Big Wave                                                         Bamboo Decking Small Wave                            sualnloss Clip
#          1860 x 140 x 2Omm         Jolt J4025Hambao Claddim_          PSRDTPC             1860x 140 x 2Omm              loist J40z5Bamihoo @ddina    Sctow P530/0{
#                                   Utor framinr            (torlockinci                                                  (tor Iiminr            @tct lockim
#                                                 P55u                ACCESSORIES                                                                           ACCESSORIES
#                                                                                                                                 31mm
#                                                                                                      4momnm    Emm  828rnim)
#                                                     P1197 84/PC                                        Zorrn                   CnM        PBBOOISEIT
#            Bamboo HaspeDeck                                           LcORTER 109               Bamboo Baffle
#                                                        Suiless Chp & Screw
#          1860x 140 x 18mm          artamne  Bumboo Clddirgdorlackinai                      2900 x 400 x 30mm
#                                                                     ACCeSSORIES
#                                                                                                                                                        Yoh
#                                                                                                                                                        FRoz
#        Bamboo Veneer Pecan Brown                  PBOO/SHEET                           Bamboo Veneer Natural Yellow                    PBOO/SHEET
#          2500 x 430 x 0.Smm                                                               2500 x 430 x 0.Smm
#        WWW modernbamboo ph                   f@OJmodernbamboo                           0939 905 8051             0917 100 9173             0939 918 0160
# ---
#                           mb                         ZENWOOD
#                           ModerM BAMBOO              SUSTAINABLE Composite Material
#    MOA-IKEA         OUR SHOWROOMS               IKEA                          mbe  MODERN BAMBOO
# SHOWROOM                                        EQBRANCE
# 2nd Floor Moa Square Ikea Building SM MOA
#     (Near 2nd Floor Ikea Main Entrance)
#              Parking nearby:
#       MOA South Parking/ Ikea Parking                                         BOYSEN
#       0939 905 8051        Mall Hours           2
#       (02) 8253 6462
#                                   ZEN                              TAPES N"    MODERN      XIAOMI
#                                                                     TILES      BAMBOO
#                        IBAMBOO           Icejl                               SHOWROOM
#                                  Ucladding
#                             Fleering           EDSA-PASAY
#                                                 SHOWROOM
#                                                  CXF Design Center, 641 EDSA Malibay, Pasay
# 1                                                0917 100 9173        8.30AM-S:3OPM Mon-Sat
# 8       MODERN               PBB                 (02) 8403 6260
#         BAMBOO   EVERGREEN BUSINESS YAMAHA
#        SHOWROOM             BANK
#            EDSA                                                          mnb
#              PASIG                                          MERALCO
#                                                             ORTAGAs
#   SHOWROOM                                      8              ORTIGAS AVE
#         MC Home Depot, Ortigas, Pasig                        L             MC HOME DEPOT
#    0939 918 0160      8.OOAM-8:OOPM Mon-Sun       2                           ORTIGAS
#                         WwW  modernbamboo ph     1I   WWW.zenwood ph
# ---
#                             WWW MODERNBAMBOO PH
#       2F MOA SQUARE IKEA BUILDING;          MALL OF ASIA, PASAY CITY
#                    641 EDSA, JSB BUILDING, PASAY CITY
#                   MC HOME DEPOT, ORTIGAS, PASIG CITY
# CONTACT NUMBERS: 0939 905 8051             0917 100 9173      0939 918 0160
#                EMAIL: MODERNBAMBOOPH@GMAILCOM
# -------------------------------------------------------------------------------------------
# Started parsing the file under job_id 7a254372-53f9-44c7-a074-681d221c26e6
# 2 - 2024-bardoline-pro-opera-brochure.pdf - GLOBAL LEADER IN
# LIGHTWEIGHT ROOFING
# SOLUTIONS
#
#
#
# ONDULINE       is well recognized globally in the
# construction industry with more than 70 years of
# experience    offering  guaranteed    protection   for
# buildings and people beneath.
#
#
#
# ONDULINE is present in more than 120 countries
# providing   clients  with  ecologically   responsible
# roofing and waterproofing solutions.
#
#
#
# ONDULINE        products are asbestos-free and
# are fully committed to customers satisfaction                      Scan this to know more
# and planet environment preservation.
#
#
#
# In  the   Philippines,   ONDULINE        started    its
# operations in 2012 in Taguig City and has
# expanded its presence nationwide through
# its authorized distributors.
#
#
#
#                                                          /ondulinephilippine@onduline_ph   www.onduline.ph  BARDOLINE     OPERA          ®  PRO
#                                                            BROWSE             CONNECT                                  Bitumen Shingles
#                                                                        SHOP                                           Ondulns
#                                                                        Basta roofing;                                              Qup
# ---
#                                                                                                      INSTALLATION INSTRUCTIONS
#   Material / Application                                                                          Preparing installation
# BARDOLINE          ®   PRO OPERA is a laminated colored bitumen shingle for roof                  Use ONDUTISS        ® STRONG membrane to cover full checking in order to achieve                            Ridges
#                                                                                                   water-tight and smooth environment.
# and wall covering.                                                                                Mark a line xy orthogonal to the direction of maximum slope of the roof (usually paral-                     Install the last row of bituminous shingles up to the ridge line and then bend it over the
#                                                                                                   lel to the eaves and to the gutter and at 33 cm from the gutter)                                            exceeding part, in order to waterproof the ridge
#                                                                                                   Mark point A in the centre of the line XY                                                                   To obtain the ridges, cut the bituminous shingles into 3 pieces (Drawing Nr. 6). Before
#                                                                                                   Mark points B and C at either side from A (for example at 150 cm)                                           installing bend and position them over the ridge line (see Drawing Nr. 7) if necessary
#                                                                                                   Starting from B and C by using a chalk line as a compass, mark point D as near as                           heat them on the reverse, sanded side
#                                                                                                   possible to the Ridge                                                                                       Fix the ridges with 2 nails on each piece which will be overlapped by the following
#                                                                                                   Join A with D                                                                                               piece (Drawing Nr. 8). The exposure of the ridge is 14.5 cm
#                                                                                                   Mark one line parallel to line AD at 16.6 cm (z) and another line parallel to line AD at
#                                                                                                   33.3 cm (k)                                                                                                                         12
#    Technical characteristics                                                                      Starting from the line xy, mark horizontal and parallel lines to the line xy, at a distance
#                                                                                                   of 14.5 cm from each other up to the ridge                                                                  1                                                                            Drawing Nr. 7 - Cutting of the ridges
#
#
#
#                                                                                                                                                                      Drawing Nr. 1 - Marking out the roof
#
#
#
#                                                                                                   Installation
#                                                                                                   Appl along the eaves 25 cm of torch-on membrane (see Drawing Nr. 2)
#                                                                                                   Install the first row of BARDOLINE           ®  PRO OPERA along the line AD (Drawing Nr. 2)
#                                                                                                   Install the second line of BARDOLINE             ®  PRO OPERA along line z (Drawing Nr. 3)                  Drawing Nr. 8 - Installation of the ridges
#                                                                                                   Install the third line of BARDOLINE           ®  PRO OPERA along line k (Drawing Nr. 3)
# ...
#  Document(id_='12785863-e935-4c59-87bc-57ac58b7be21', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\UGC_Megahirib_08232022.pdf', 'file_name': 'UGC_Megahirib_08232022.pdf', 'file_type': 'application/pdf', 'file_size': 2651602, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='                            GALVASTEEL\n                 PHINMA COMPANY\n   1    N\n        8\n     TATAK\n 0 UNOM\n    VALUE\nMECAHIRIB\n Lowsloped roofing for institutional, warehouse and commercial establishments\n   UnionGalvasteelCorpPHINMAWWWugc-ph        Sa Tibay at Ganda; PANALO KAI\n---\n                                                                                              PRODUCT INFO\n\n\n\nSUBSTRATES                          Hot-dip Metallic Coated Steel                                         PAINT COATING SYSTEM                      Oven baked Oil free Polyester topcoat over a corro-\n                                    - Hot-dip Zinc-Coated Steel                                                                                     sion-resistant Primer with Oil free Polyester backing coat\n                                    - Hot-dip 55% Aluminum-Zinc Alloy Coated Steel                                                                  PVDF SMP, available upon request\n\n\n\nNOMINAL THICKNESS                   0.50 mm to 0.80 mm                                                    PAINT COATING                             Topcoat : 12 – 15 microns\nFEED WIDTH                          1220 mm                                                               THICKNESS                                 Backing Coat : 4–8 microns\n                                                                                                          AVAILABLE COLORS                          Red, Green, Brown, Beige, Blue, White\nEFFECTIVE COVERAGE                  918 mm (+/- 10mm)                                                                                               Charcoal Gray, Teracotta Orange, Fire Red\n\n\n\nRIB HEIGHT                          90 mm (+/- 10mm)                                                                                                Other Colors available with terms and conditions applied\n\n\n\n                                                                                                          LENGTH                                    Customized length available with terms and conditions.\n* Bended Accessories Available (Stainless materials available upon request)                                                                         Onsite rollforming for longer panels\n   PRODUCT SPECIFICATIONS\n                      MEGAHIRIB BRACKET\n  SIZES OF TEKSCREW:                                                                                                                                                                                                 VegArib\n     Megarib Panel to Bracket          12 *35      Steel                                                                                                                                                             IhSULATICH\n                                       12X35          witnout insulation\n     Bracket to Purlins                12X45          with 1Omm thick insulation\n                                       12X55       If with 15          25mm thick insulation\n                                       12X65       If with SOmm thick Insulation tock woo\n                                              HANDLING, STORAGE AND INSTALLATION GUIDELINES\n\n\n\n1.       Lift and bring down ...
#  Document(id_='83b7b2ad-42da-462d-934d-dd7f754b2908', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\UGC_Minirib_08242022.pdf', 'file_name': 'UGC_Minirib_08242022.pdf', 'file_type': 'application/pdf', 'file_size': 1993696, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="                             GALVASTEEL\n                  PHINMA COMPANY\n   1    NTE0\n     TATAK\n 0 UNOM\n    VALUE\nMINIRIB\n Used for Cladding; Ceilings, Eaves & Wall;\n   UnionGalvasteelCorpPHINMAWWWugc-ph        Sa Tibay at Ganda; PANALO KAI\n---\n                                                                                             PRODUCT INFO\n\n\n\nSUBSTRATES                          Hot-dip Metallic Coated Steel                                      PAINT COATING SYSTEM                      Oven baked Oil free Polyester topcoat over a corro-\n                                    - Hot-dip Zinc-Coated Steel                                                                                  sion-resistant Primer with Oil free Polyester backing coat\n                                    - Hot-dip 55% Aluminum-Zinc Alloy Coated Steel                                                               PVDF, SMP, available upon request\n\n\n\nNOMINAL THICKNESS                   0.30 mm to 0.60 mm                                                 PAINT COATING THICKNESS                   Topcoat : 12 – 15 microns\nFEED WIDTH                          915 mm and 1220 mm                                                                                           Backing Coat : 4–8 microns\n                                                                                                       AVAILABLE COLORS                          Red, Green, Brown, Beige, Blue, White\nEFFECTIVE COVERAGE                  780 mm and 1064 mm (+/- 5mm)                                                                                 Charcoal Gray, Teracotta Orange, Fire Red\n\n\n\nRIB HEIGHT                          10 mm                                                                                                        Other Colors available with terms and conditions applied\n\n\n\n** Inverted Minirib Profile Available                                                                  LENGTH                                    Customized length available with terms and conditions\n   PRODUCT SPECIFICATIONS                                                                                          FLD UAIA\n   APPLICATION: CEILING AND WALLING                                                           STANDARD MINIRIB PROFILE\n   TEKSCREW IF NO INSULATION = 12X35                                                                              FLDO HAILAL   Lip                               im)\n                                                                                                                      HATUHAL\n                                                                                              INVERTED MINIRIB PROFILE  JILMMITER\n                                             HANDLING, STORAGE AND INSTALLATION GUIDELINES\n\n\n\n1.      Lift and bring down panels at its horizontal sides. Lifting may require two to three persons for longer panels.\n2.      Panels should be stored in dry, shaded and good ventilated area. Avoid contact with wet lumber, soil or chemical contamination. Provide cover if not for\n        immediate use.\n3.      When panels become wet during storage, separate without delay, remove surface moisture with clean cloth and stack so air can circulate and complete the drying\n ...
#  Document(id_='efea10ae-965f-48cf-b9ac-4c60a88919cf', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\UGC_Multirib8_05082023.pdf', 'file_name': 'UGC_Multirib8_05082023.pdf', 'file_type': 'application/pdf', 'file_size': 1950793, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='                                   GALVASTEEL                                        1   N 7\n                      PHINMA COMPANY                                                  TATAK  4\n                                                                                      VALUE\nMEW\n    STIFFER AND BETTER DESIGN OF RIB ROOFING\n    8 RIBS WITH CAPILLARY GROOVES THAT SERVE AS AN ANTI-LEAK FEATURE\n    MOST APPLICABLE FOR TYPHOON PRONE AREAS\n    CAN ALSO BE USED FOR CEILING AND WALL CLADDING APPLICATIONS\n MULTI-RIB8\n  Roofing and cladding for residential; institutional and commercial establishments:\n  @UnionGalvasteelCorpPHINMA         WWWugC-ph Sa     Tibay    at Ganda; PANALO KAI\n---\n                                                                                        PRODUCT INFO\n\n\n\nSUBSTRATES                       Hot-dip Metallic Coated Steel                                     PAINT COATING SYSTEM                   Oven-baked oil-free polyester topcoat over a corrosion-\n                                 - Hot-dip Zinc-Coated Steel                                                                              resistant primer with oil-free polyester backing coat.\n                                 - Hot-dip 55% Aluminum-Zinc Alloy Coated Steel                                                           PVDF and SMP are also available upon request.\n\n\n\nNOMINAL THICKNESS                0.30mm to 0.60mm                                                  PAINT COATING THICKNESS                Topcoat : 12 – 15 microns\nFEED WIDTH                       1220 mm                                                                                                  Backing Coat : 4–8 microns\n                                                                                                   AVAILABLE COLORS                       Red, Green, Brown, Beige, Blue, White\nEFFECTIVE COVERAGE               1005mm (+/- 10mm)                                                                                        Charcoal Gray, Teracotta Orange, Fire Red\n\n\n\nRIB DIMENSION                    H: 20mm, Pitch: 61mm, Top Base: 29mm                                                                     Other Colors available with terms and conditions applied\n\n\n\n                                                                                                   LENGTH                                 8, 10, 12 feet standard\n                                                                                                                                          Customized length available with terms and conditions\n* Bended Accessories Available (Stainless materials available upon request)                                                               Onsite rollforming for longer panels\n                                                                                                                        ADVANTAGES                                RECOMENDED APPLICATIONS\n                                                                                                                       The Multi-Rib8 has an                      PROJECTS\n                                                                                                                         -rib feature with\n           ...

# %%
# show the metadata of each document
for idx, doc in enumerate(documents):
    print(f"{idx} - {doc.metadata}")
# Out:
# 0 - {'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_name': '03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_type': 'application/pdf', 'file_size': 1816568, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}
# 1 - {'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduvilla-tile_compressed_0.pdf', 'file_name': '03-2024-onduvilla-tile_compressed_0.pdf', 'file_type': 'application/pdf', 'file_size': 2387566, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}
# 2 - {'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\092123_ModernBamboo_Catalogue.pdf', 'file_name': '092123_ModernBamboo_Catalogue.pdf', 'file_type': 'application/pdf', 'file_size': 9046826, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}

# %%
# show the file name of each document
for idx, doc in enumerate(documents):
    print(f"{idx} - {doc.metadata['file_name']}")

# %%
# show the file name and the text content of each document
for idx, doc in enumerate(documents):
    print(f"{idx} - {doc.metadata['file_name']} - {doc.text}")

# %%
# Asynchronous execution:
documents = await reader.aload_data()

print(len(documents))
# Out:
# Started parsing the file under job_id e883d3d8-5440-494c-85a4-a4bc6ea25e1c
# Started parsing the file under job_id 30de12b2-a8fd-4af8-ab44-fbf3ec97632c
# Started parsing the file under job_id 67644102-40ba-4b59-8c13-957491d7de76
# 3

# %% [markdown]
# ## Others: Using prompts to extract information
#
# You can also retrieve data from PDF using prompt instructions. Risks include returning information not explicitly stated, having misinterpretations, and incorrectly identifying characters.

# %%
# with parsing instruction
from llama_parse import LlamaParse

my_instructions = """
The provided document is a product brochure containing images and information about the product. it may or may not contain tables. Try to present these information in a clear and cohesive way, and in text format only.
"""

parser = LlamaParse(
    api_key = "", # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type = "markdown", # "markdown" and "text" are available
    parsing_instruction=my_instructions
)

print(parser.load_data("./sample_data/hd_simplified-installation_onduline_1.pdf")[0].text)
# Out:
# Started parsing the file under job_id 98e541bc-11e5-4b01-a1be-d44aa2f94a77
# # Onduline Product Brochure
#
# # Onduline Product Brochure
#
# 20 x =
#
# 1
#
# 21 3 5 9 10 2
#
# 9° - 15° (15% - 27%)
#
# 2
#
# > 15° (> 27%)
#
# 3
#
# 12du
#
# 15 cm
#
# min
#
# 4
#
# Onduline®
#
# 35, rue Baudin, 92300 Levallois-Perret, FRANCE
#
# www.onduline.com
#
# #06_FicheInstallation_Onduline.indd 1 09/12/14 09:17

# %%
# with parsing instruction
from llama_parse import LlamaParse

my_instructions = """
The provided document is a product brochure containing images and information about the product. Present all information about the product while considering the context of the images and its connection to the text in the document. Don't describe the product unless otherwise stated in the document.
"""

parser = LlamaParse(
    api_key = "", # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type = "markdown", # "markdown" and "text" are available
    parsing_instruction=my_instructions
)

print(parser.load_data("./sample_data/hd_simplified-installation_onduline_1.pdf")[0].text)
# Out:
# Started parsing the file under job_id 1ec804ed-36aa-4a09-b588-f86c0513d09b
# # Onduline Product Brochure
#
# Product Information:
#
# Dimensions: 15 cm minimum
#
# Material: Onduline®
#
# Address: 35, rue Baudin, 92300 Levallois-Perret, FRANCE
#
# Website: www.onduline.com
#
# Installation Guidelines:
#
# Angle Range: 9° - 15° (15% - 27%)
#
# For angles greater than 15° (> 27%), refer to section 5b
#
# Document ID: #06_FicheInstallation_Onduline.indd 1
#
# Date: 09/12/14 09:17

# %% [markdown]
# ## 5. Loading Extracted Text to a Pinecone Server

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# The extracted text must be in markdown format. Run any one of the three methods:

# %%
# Method 1: Loading a single doc without prompt
from llama_parse import LlamaParse

my_instructions = """
The provided document is a product brochure containing images and information about the product. Present all information about the product while considering the context of the images and its connection to the text in the document. Don't describe the product unless otherwise stated in the document.
"""

parser = LlamaParse(
    api_key = "", # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type = "markdown", # "markdown" and "text" are available
    parsing_instruction=None
)

extracted_text = parser.load_data("./sample_data/hd_simplified-installation_onduline_1.pdf")
extracted_text
# Out:
# Started parsing the file under job_id f6c4766c-0911-4fbb-bda3-54f6c72f5e06
# [Document(id_='cd6cf9e2-d75e-4add-991a-4e341007fa46', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='|20 x =|\n|---|\n|1|2|3|\n|21|3|5 9 10 2|\n|9° - 15° (15% - 27%)|\n|&gt; 15° (&gt; 27%)|\n|4|5a|5b|\n| | |12du|15 cm min|\n|Onduline®|35, rue Baudin , 92300 Levallois-Perret, FRANCE|www.onduline.com|\n|#06_FicheInstallation_Onduline.indd 1| |09/12/14 09:17|', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
# Method 2: Loading multiple docs without prompt
from llama_index.core import SimpleDirectoryReader
from llama_parse import LlamaParse

parser = LlamaParse(
    api_key = "", # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type = "markdown" # "markdown" and "text" are available
)

file_extractor = {".pdf": parser}

reader = SimpleDirectoryReader(input_dir="./sample_data", 
                            #    required_exts=[".pdf", ".docx"],
                                file_extractor=file_extractor,
                                recursive=False, # doesn't get files from subdirectories also
                                num_files_limit= 3) #sets number of documents to read

extracted_text = reader.load_data()
extracted_text
# Out:
# Started parsing the file under job_id 30acbdf8-cbe1-405d-9270-d067023bcbfc
# Started parsing the file under job_id 9cfbf61e-dee2-447b-820b-94323568e961
# Started parsing the file under job_id 55065124-1ba5-47a6-b756-547b55ff47ad
# [Document(id_='831a6990-eff1-4997-8285-febe9bbe6a04', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_name': '03-2024-onduline-classic-brochure_compressed_2.pdf', 'file_type': 'application/pdf', 'file_size': 1816568, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='# GLOBAL LEADER IN LIGHTWEIGHT ROOFING SOLUTIONS\n\nONDULINE® Classic\n\nONDULINE is well recognized globally in the construction industry with 80 years of experience offering guaranteed protection for buildings and people beneath.\n\nONDULINE is present in more than 100 countries providing clients with ecologically responsible roofing and waterproofing solutions. Scan this to know more\n\nONDULINE products are asbestos-free and are fully committed to customer satisfaction and planet environment preservation.\n\n/ondulinephilippines@onduline_ph 0917 713 5616 www.ph.onduline.com\n\nIn the Philippines, ONDULINE started its operations in 2012 in Taguig City, having a warehouse in Cebu and Valenzuela to efficiently serve our clients. BROWSE SHOP CONNECT Basta roofing; Onduline\n---\n## Color Range\n\n|BLACK classic|BROWN classic|\n|---|---|\n|GREEN classic|RED classic|\n\n### Product Characteristics\n\n|Length|200cm|\n|---|---|\n|Width|95 cm|\n|Thickness|3 mm|\n|Height of Corrugation|38 mm|\n|Pitch of Module|95 mm|\n|Surface|1.90 m|\n|Weight of Product|6.5 kg|\n|Weight per m|3.4 kg/m|\n|Number of Corrugations|10|\n\n### Installation Procedure\n\nLaying of Purlins\nFixing of sheets\n\nHalfsheet\n- Fix the bottom purlin.\n- The purlin spacing has to be maintained at 45cm.\n- Ensure that the purlins are in one straight line & parallel to each other.\n- 5-10 degrees (24cm purlin spacing) - 20pcs screws (8+4+4+4)\n- a. SIDE overlap - 2 corrugations\n- b. Top Overlap - 32cm sheets\n- 10 degrees up (45cm purlin spacing) - 14pcs screws (5+3+3+3)\n- a. SIDE overlap - 1 corrugation\n- b. Top Overlap - 20cm\n\nFollowing the overlapping rules is important to ensure a total waterproof over time. Side and end overlapping vary according to the roof pitches.\n- For the end overlap, use minimum 20 cm.\n- For the side overlap, use minimum 1 corrugation.\n- Minimum of 14 screws should be drilled per sheet:\n- 5 screws at each corrugation at the end overlap or eaves\n- 3 screws at intermediate purlin of the sheet\n- 3 screws at second intermediate purlin of the sheet\n- 3 screws at third intermediate purlin of the sheet\n\nSheet fixing\n- Select the correct type of drill screw to suit purlin type.\n- Place the head of the drill screw in the socket of the drive tool. Align the top side of the corrugation with the centre of the purlin.\n- Drive the drill screw through the top of the corrugation and the purlin until the corrugation is correctly stressed.\n- The use of the drill with an adjustable torque setting is recommended to avoid over compressing the corrugation.\n- Always use Onduline fasteners for this.\n\nRidge fixing\n- Add an extra purlin when necessary if the distance between the last purlin and the ridge is greater than 15cm.\n- Start the ridge at the opposite end of the roof from prevailing winds.\n- Maintain 15 cm minimum overlapping between ridges.\n\nRubber Filler (Optional)\n- Our Corrugated Ventilated Filler is designed to prevent birds and other animals from entering the roof space, at the eave and ridge.\n- Easy to install\n- Available in all Onduvilla colors\n- 15-year warranty\n\nHips\n- Fix the hip before the ridge.\n- Fasten the ridge to the purlins.\n- Overlay and clean the ridges if necessary.\n\nValleys\n- The vertical va ...
#  Document(id_='82aa76b2-7bbf-4896-93e2-352220f56c6f', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\03-2024-onduvilla-tile_compressed_0.pdf', 'file_name': '03-2024-onduvilla-tile_compressed_0.pdf', 'file_type': 'application/pdf', 'file_size': 2387566, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='## GLOBAL LEADER IN LIGHTWEIGHT ROOFING SOLUTIONS\n\nONDULINE is well recognized globally in the construction industry with 80 years of experience offering guaranteed protection for buildings and people beneath.\n\nONDULINE is present in more than 100 countries providing clients with ecologically responsible roofing and waterproofing solutions. Scan this to know more.\n\nONDULINE products are asbestos-free and are fully committed to customers satisfaction and planet environment preservation.\n\nIn the Philippines, ONDULINE started its operations in 2012 in Taguig City, having warehouse in Cebu and Valenzuela to efficiently serve our clients.\n\nConnect with ONDULINE:\n\nFacebook: /ondulinephilippines\n\nInstagram: @onduline_ph\n\nPhone: 0917 713 5616\n\nWebsite: www.ph.onduline.com\n\nBROWSE | CONNECT\n\nSHOP\nBasta roofing;\nOnduline\n---\n## Color Range\n\nPigmented Colors\n\nInstallation principles\n\nLaying of purlins - Purlins have to be placed at 32cm distance, centre to centre. Since there is an overhang of 5cm at the eaves, the distance between the first and second purlin is 27cm, centre to centre.\n\nStart installation at eave, in pe opposite direction of pe prevailing wind. Position pe Slim cap can be used for pitches up to 30°. Above pat limit, pe standard ridge piece should be used. Thanks to pe higher pitch, pe apron piece is not necessary and pe ridge is watertight.\nThe corrugated ventilated filler can be fixed below pe ridge piece, in order to prevent birds or oper animals entering into pe roof space. Overlap between ridges needs to be maintained at 15cm.\n\n## Product Characteristics\n\n|Length|107 cm|\n|---|---|\n|Width|40 cm|\n|Thickness|3 mm|\n|Height of Corrugation|38 mm|\n|Pitch of Module|195 mm|\n|Gross Surface|0.43 m^2|\n|Weight of Product|1.3 kg|\n|Weight per gross surface|3.1 kg/m^2|\n|Corrugation + Flats|6 + 5|\n\n## Fixing\n\nONDUVILLA® is to be fixed at each overlap and corrugation with ONDUVILLA® fasteners. Fix the tiles following the order described above, between the 2 overlapping guides. Do not fix those corrugations that will be overlapped by the next tile or verge piece.\n\n## Ridges\n\nEnsure that the maximum distance from the ridge point to the next purlin is 15 cm. If necessary, add an extra purlin to maintain this distance.\n\n## Valley\n\nPrepare the support. Fix the screws on top of corrugations, into the supporting batten.\n\n## Side wall Abutment\n\nFix the tile to the side wall with an aluminium Z-profile. Secure the watertightness with a silicone mastic.\n\n## Accessories\n\nOnduline RIDGES 900mm x 420mm\nLarge and flexible ridge piece which is needed for roofs wip pitch above 30 degrees. Does not require additional waterproofing device.\nSpeedy SCREWS 4.2mm x 65mm\nSelf drilling screw for fastening of roofing sheet to steel and wood purlins.\nApron Abutment\nAluminium Z profile is fixed to pe wall, and a line of silicon mastic is necessary for pe watertightness.\nVERGE 1040mm x 109mm\nSelf adhesive flashing tape used for water tightness at pe hips.\nONDUBAND\nLike pe tiles, apron pieces and slim caps are to be overlapped against prevailing wind. Slim caps and closure cap have to be fixed on top of pe corrugations. If necessary, for a better adaptation to pe slope of pe roof, part B of pe closure ca ...
#  Document(id_='9b04fade-e393-4dfe-951e-53fb3263866a', embedding=None, metadata={'file_path': 'c:\\Users\\Shiro\\Document & Files\\Educational Materials\\Programming\\Python Files\\sample_data\\092123_ModernBamboo_Catalogue.pdf', 'file_name': '092123_ModernBamboo_Catalogue.pdf', 'file_type': 'application/pdf', 'file_size': 9046826, 'creation_date': '2024-05-10', 'last_modified_date': '2024-05-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='MODERN BAMBOO\n   THE BAMBOO EXPERT\n      CATALOGUE 2023\n---\n# MODERNOBEZAMBOO\n\nFinished project:\nMcdo Calasiao, Pangasinan\nEco-Friendly Sustainable Material\n\nCladding\nFlooring\nDecking\nCeiling\nBaffle\nSlats\n---\n## ABOUT US\n\nAt Modern Bamboo, we are dedicated to providing high-quality, eco-friendly, and sustainable materials for flooring, walls, and ceilings, both for indoor and outdoor spaces. Our mission is to offer innovative and stylish solutions that not only enhance the aesthetics of your living or working environment but also contribute to a greener, more sustainable future.\n\nWe understand the importance of preserving our planet and minimizing our ecological footprint. That\'s why all our products are carefully sourced and manufactured with a strong commitment to sustainability. We specialize in bamboo, a fast-growing and renewable resource that offers remarkable strength and durability while being gentle on the environment.\n\n## WHY CHOOSE US?\n\nDiscover Modern Bamboo, your go-to destination for eco-friendly and sustainable materials for indoor and outdoor flooring, walls, and ceilings. With our carefully sourced bamboo products, we offer stylish and environmentally conscious choices for your design needs. Choose us for exceptional quality, versatile styles, and expert guidance, as we strive to make a positive impact on our planet while creating stunning spaces that inspire.\n\n## OUR COMMITMENTS\n\nAt Modern Bamboo, we are committed to building a sustainable future. We prioritize eco-friendly sourcing, using renewable materials like bamboo to reduce deforestation. Our manufacturing processes are designed to be sustainable, minimizing waste and emissions. We provide high-quality and durable products that stand the test of time. Our versatile design solutions offer style and functionality while minimizing environmental impact. Join us in creating a greener, more sustainable world through our commitment to eco-friendly practices.\n\nWWWmodernbamboo-ph | f@modernbamboo | 0939 905 8051 | 0917 100 9173 | 0939 918 0160\n---\n## mb \'BAMBOO THE BAMBOO EXPERT\n\n|Quality Raw Materials|E1 Standard|Advanced Technology|\n|---|---|---|\n|We use 5-year old matured bamboo which is most compact, most durable and most suited for bamboo flooring|We use 8 coats of odorless, healthy and scratch-resistant German Treffert paint|Our partner manufacturing plant has over 20 years of experience using the most advanced technology in manufacturing|\n\n|High-tech Locking & PE Foam|Termite Treated|Trusted Supplier|\n|---|---|---|\n|Click locking system for easy installation, removal, and repair|Our planks are treated against termites|Our company has been supplying construction materials since 2010 and is conveniently located along EDSA Pasay|\n\nWe use PE foam with a special HDPE layer.\n\nwww.modernbamboo-ph | f@modernbamboo | 0939 905 8051 | 0917 100 9173 | 0939 918 0160\n---\n|Pecan Brown|5565/BOX (6pcs)|ACCESSORIES|Walnut Brown|3900/BOX (6pcs)|ACCESSORIES|\n|---|---|---|---|---|---|\n|1020 x 130 x 15mm|Baseboard|T Molding|1850 x 135 x 14mm|Baseboard|T Molding End Profile|\n|End Profile Quarter Round| | |Stair Nosing Quarter Round| | |\n|3900/BOX (6pcs)| | |3900/BOX (6pcs)| | |\n|Natural Yellow|T Molding|ACCESSORIES|Tea Brown|ACCESSORIES| |\n|1850 x 135 ...

# %%
# Method 3: Parsing with prompts
from llama_parse import LlamaParse

my_instructions = """
The provided document is a product brochure containing images and information about the product. Present all information about the product while considering the context of the images and its connection to the text in the document. Don't describe the product unless otherwise stated in the document.
"""

parser = LlamaParse(
    api_key = "", # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type = "markdown", # "markdown" and "text" are available
    parsing_instruction=my_instructions
)

extracted_text = parser.load_data("./sample_data/hd_simplified-installation_onduline_1.pdf")
extracted_text
# Out:
# Started parsing the file under job_id dbd2270b-38ff-4f18-b6e2-ab5ddba72c4d
# [Document(id_='57161244-3ab9-450e-9b4c-5e7caa1a70f3', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Onduline Product Brochure\n\nProduct Information:\n\nDimensions: 15 cm minimum\n\nMaterial: Onduline®\n\nAddress: 35, rue Baudin, 92300 Levallois-Perret, FRANCE\n\nWebsite: www.onduline.com\n\nInstallation Guidelines:\n\nAngle Range: 9° - 15° (15% - 27%)\n\nFor angles greater than 15° (> 27%), refer to section 5b\n\nDocument ID: #06_FicheInstallation_Onduline.indd 1\n\nDate: 09/12/14 09:17', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %% [markdown]
# Then run these code below to obtain the embeddings and send it to the Pinecone server.

# %%
from langchain.vectorstores import Chroma, Pinecone
from langchain.embeddings.openai import OpenAIEmbeddings
import pinecone

# %%
embeddings = OpenAIEmbeddings(openai_api_key="")

# %%
#initialize pinecone
pinecone.Pinecone(
    api_key="",
    environment=""
)
index_name = "" # name of index in pinecone

# %%
#creates embeddings to the texts and passes them up to pinecone
docsearch = Pinecone.from_texts([t.text for t in extracted_text],
                                embeddings,
                                index_name=index_name)

# %% [markdown]
# The index in the pinecone should be filled with vector data after the code above.
